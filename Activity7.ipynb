# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')
import folium
from folium.plugins import HeatMap

# %%
chicago_crimes = pd.read_csv('Chicago_Crimes.csv', encoding='ISO-8859-1')

# %%
chicago_crimes
# Out:
#               ID Case Number                    Date                  Block  \
# 0       13439321    JH237424  04/14/2024 12:00:00 AM    040XX S PRAIRIE AVE
# 1       13437420    JH234779  04/14/2024 12:00:00 AM      023XX W CERMAK RD
# 2       13428676    JH224478  04/14/2024 12:00:00 AM    043XX W LE MOYNE ST
# 3       13429357    JH225293  04/14/2024 12:00:00 AM       039XX W ADAMS ST
# 4       13430098    JH226395  04/14/2024 12:00:00 AM       011XX W 112TH PL
# ...          ...         ...                     ...                    ...
# 249118  13805239    JJ217509  04/12/2025 12:00:00 AM     029XX W LOGAN BLVD
# 249119  13804023    JJ215813  04/12/2025 12:00:00 AM    094XX S HARVARD AVE
# 249120  13803926    JJ215943  04/12/2025 12:00:00 AM  084XX S VINCENNES AVE
# 249121  13803475    JJ215338  04/12/2025 12:00:00 AM    050XX S ABERDEEN ST
# 249122  13804512    JJ216668  04/12/2025 12:00:00 AM    012XX W CARROLL AVE
#
# ...

# %% [markdown]
# <h1>THEFT</h1>
# <hr>

# %%
THEFT = chicago_crimes[chicago_crimes['Primary Type'] == "THEFT"]

# %%
THEFT_loc_list = THEFT.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_THEFT = THEFT_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapTHEFT = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_THEFT).add_to(my_mapTHEFT)
my_mapTHEFT.save('THEFT.html')
print("data save to THEFT.html")
# Out:
# data save to THEFT.html

# %%
my_mapTHEFT
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>BATTERY</h1>
# <hr>

# %%
BATTERY = chicago_crimes[chicago_crimes['Primary Type'] == "BATTERY"]
BATTERY_loc_list = BATTERY.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_BATTERY = BATTERY_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapBATTERY = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_BATTERY).add_to(my_mapBATTERY)
my_mapBATTERY.save('BATTERY.html')
print("data save to BATTERY.html")
my_mapBATTERY
# Out:
# data save to BATTERY.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>CRIMINAL DAMAGE</h1>
# <hr>

# %%
CD = chicago_crimes[chicago_crimes['Primary Type'] == "CRIMINAL DAMAGE"]
CD_loc_list = CD.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_CD = CD_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapCD = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_CD).add_to(my_mapCD)
my_mapCD.save('CRIMINALDAMAGE.html')
print("data save to CRIMINALDAMAGET.html")
my_mapCD
# Out:
# data save to CRIMINALDAMAGET.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>ASSAULT</h1>
# <hr>

# %%
ASSAULT = chicago_crimes[chicago_crimes['Primary Type'] == "ASSAULT"]
ASSAULT_loc_list = ASSAULT.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_ASSAULT = ASSAULT_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapASSAULT = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_ASSAULT).add_to(my_mapASSAULT)
my_mapASSAULT.save('ASSAULT.html')
print("data save to ASSAULT.html")
my_mapASSAULT
# Out:
# data save to ASSAULT.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>MOTOR VEHICLE THEFT</h1>
# <hr>

# %%
MotorVT = chicago_crimes[chicago_crimes['Primary Type'] == "MOTOR VEHICLE THEFT"]
MotorVT_loc_list = MotorVT.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_MotorVT = MotorVT_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapMotorVT = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_MotorVT).add_to(my_mapMotorVT)
my_mapMotorVT.save('MotorVT.html')
print("data save to MotorVT.html")
my_mapMotorVT
# Out:
# data save to MotorVT.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>OTHER OFFENSE</h1>
# <hr>

# %%
OtherO = chicago_crimes[chicago_crimes['Primary Type'] == "OTHER OFFENSE"]
OtherO_loc_list = OtherO.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_OtherO = OtherO_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapOtherO = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_OtherO).add_to(my_mapOtherO)
my_mapOtherO.save('OtherO.html')
print("data save to OtherO.html")
my_mapOtherO
# Out:
# data save to OtherO.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>DECEPTIVE PRACTICE</h1>
# <hr>

# %%
dp = chicago_crimes[chicago_crimes['Primary Type'] == "DECEPTIVE PRACTICE"]
dp_loc_list = dp.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_dp = dp_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapdp = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_dp).add_to(my_mapdp)
my_mapdp.save('dp.html')
print("data save to dp.html")
my_mapdp
# Out:
# data save to dp.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>BURGLARY</h1>
# <hr>

# %%
BURGLARY = chicago_crimes[chicago_crimes['Primary Type'] == "BURGLARY"]
BURGLARY_loc_list = BURGLARY.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_BURGLARY = BURGLARY_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapBURGLARY = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_BURGLARY).add_to(my_mapBURGLARY)
my_mapBURGLARY.save('BURGLARY.html')
print("data save to BURGLARY.html")
my_mapBURGLARY
# Out:
# data save to BURGLARY.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>ROBBERY</h1>
# <hr>

# %%
ROBBERY = chicago_crimes[chicago_crimes['Primary Type'] == "ROBBERY"]
ROBBERY_loc_list = ROBBERY.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_ROBBERY = ROBBERY_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapROBBERY = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_ROBBERY).add_to(my_mapROBBERY)
my_mapROBBERY.save('ROBBERY.html')
print("data save to ROBBERY.html")
my_mapROBBERY
# Out:
# data save to ROBBERY.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>WEAPONS VIOLATION</h1>
# <hr>

# %%
WEAPONS_VIOLATION = chicago_crimes[chicago_crimes['Primary Type'] == "WEAPONS VIOLATION"]
WEAPONS_VIOLATION_loc_list = WEAPONS_VIOLATION.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_WEAPONS_VIOLATION = WEAPONS_VIOLATION_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapWEAPONS_VIOLATION = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_WEAPONS_VIOLATION).add_to(my_mapWEAPONS_VIOLATION)
my_mapWEAPONS_VIOLATION.save('WEAPONS_VIOLATION.html')
print("data save to WEAPONS_VIOLATION.html")
my_mapWEAPONS_VIOLATION
# Out:
# data save to WEAPONS_VIOLATION.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>NARCOTICS</h1>
# <hr>

# %%
NARCOTICS = chicago_crimes[chicago_crimes['Primary Type'] == "NARCOTICS"]
NARCOTICS_loc_list = NARCOTICS.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_NARCOTICS = NARCOTICS_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapNARCOTICS = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_NARCOTICS).add_to(my_mapNARCOTICS)
my_mapNARCOTICS.save('NARCOTICS.html')
print("data save to NARCOTICS.html")
my_mapNARCOTICS
# Out:
# data save to NARCOTICS.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>CRIMINAL TRESPASS</h1>
# <hr>

# %%
CT = chicago_crimes[chicago_crimes['Primary Type'] == "CRIMINAL TRESPASS"]
CT_loc_list = CT.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_CT = CT_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapCT = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_CT).add_to(my_mapCT)
my_mapCT.save('CT.html')
print("data save to CT.html")
my_mapCT
# Out:
# data save to CT.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>OFFENSE INVOLVING CHILDREN</h1>
# <hr>

# %%
OFC = chicago_crimes[chicago_crimes['Primary Type'] == "OFFENSE INVOLVING CHILDREN"]
OFC_loc_list = OFC.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_OFC = OFC_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapOFC = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_OFC).add_to(my_mapOFC)
my_mapOFC.save('OFC.html')
print("data save to OFC.html")
my_mapOFC
# Out:
# data save to OFC.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>CRIMINAL SEXUAL ASSAULT</h1>
# <hr>

# %%
CSA = chicago_crimes[chicago_crimes['Primary Type'] == "CRIMINAL SEXUAL ASSAULT"]
CSA_loc_list = CSA.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_CSA = CSA_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapCSA = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_CSA).add_to(my_mapCSA)
my_mapCSA.save('CSA.html')
print("data save to CSA.html")
my_mapCSA
# Out:
# data save to CSA.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>PUBLIC PEACE VIOLATION</h1>
# <hr>

# %%
PPV = chicago_crimes[chicago_crimes['Primary Type'] == "PUBLIC PEACE VIOLATION"]
PPV_loc_list = PPV.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_PPV = PPV_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapPPV = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_PPV).add_to(my_mapPPV)
my_mapPPV.save('PPV.html')
print("data save to PPV.html")
my_mapPPV
# Out:
# data save to PPV.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>SEX OFFENSE</h1>
# <hr>

# %%
sex_o = chicago_crimes[chicago_crimes['Primary Type'] == "SEX OFFENSE"]
sex_o_loc_list = sex_o.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_sex_o = sex_o_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapsex_o = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_sex_o).add_to(my_mapsex_o)
my_mapsex_o.save('sex_o.html')
print("data save to sex_o.html")
my_mapsex_o
# Out:
# data save to sex_o.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>INTERFERENCE WITH PUBLIC OFFICER</h1>
# <hr>

# %%
IWPO = chicago_crimes[chicago_crimes['Primary Type'] == "INTERFERENCE WITH PUBLIC OFFICER"]
IWPO_loc_list = IWPO.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_IWPO = IWPO_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapIWPO = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_IWPO).add_to(my_mapIWPO)
my_mapIWPO.save('IWPO.html')
print("data save to IWPO.html")
my_mapIWPO
# Out:
# data save to IWPO.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>HOMICIDE</h1>
# <hr>

# %%
HOMICIDE = chicago_crimes[chicago_crimes['Primary Type'] == "HOMICIDE"]
HOMICIDE_loc_list = HOMICIDE.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_HOMICIDE = HOMICIDE_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapHOMICIDE = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_HOMICIDE).add_to(my_mapHOMICIDE)
my_mapHOMICIDE.save('HOMICIDE.html')
print("data save to HOMICIDE.html")
my_mapHOMICIDE
# Out:
# data save to HOMICIDE.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>STALKING</h1>
# <hr>

# %%
STALKING = chicago_crimes[chicago_crimes['Primary Type'] == "STALKING"]
STALKING_loc_list = STALKING.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_STALKING  = STALKING_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapSTALKING = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_STALKING).add_to(my_mapSTALKING)
my_mapSTALKING.save('STALKING.html')
print("data save to STALKING.html")
my_mapSTALKING
# Out:
# data save to STALKING.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>ARSON</h1>
# <hr>

# %%
ARSON = chicago_crimes[chicago_crimes['Primary Type'] == "ARSON"]
ARSON_loc_list = ARSON.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_ARSON = ARSON_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapARSON = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_ARSON).add_to(my_mapARSON)
my_mapARSON.save('ARSON.html')
print("data save to ARSON.html")
my_mapARSON
# Out:
# data save to ARSON.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>PROSTITUTION</h1>
# <hr>

# %%
PROSTITUTION = chicago_crimes[chicago_crimes['Primary Type'] == "PROSTITUTION"]
PROSTITUTION_loc_list = PROSTITUTION.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_PROSTITUTION = PROSTITUTION_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapPROSTITUTION = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_PROSTITUTION).add_to(my_mapPROSTITUTION)
my_mapPROSTITUTION.save('PROSTITUTION.html')
print("data save to PROSTITUTION.html")
my_mapPROSTITUTION
# Out:
# data save to PROSTITUTION.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>CONCEALED CARRY LICENSE VIOLATION</h1>
# <hr>

# %%
CCLV = chicago_crimes[chicago_crimes['Primary Type'] == "CONCEALED CARRY LICENSE VIOLATION"]
CCLV_loc_list = CCLV.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_CCLV = CCLV_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapCCLV = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_CCLV).add_to(my_mapCCLV)
my_mapCCLV.save('CCLV.html')
print("data save to CCLV.html")
my_mapCCLV
# Out:
# data save to CCLV.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>LIQUOR LAW VIOLATION</h1>
# <hr>

# %%
LLV = chicago_crimes[chicago_crimes['Primary Type'] == "LIQUOR LAW VIOLATION"]
LLV_loc_list = LLV.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_LLV = LLV_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapLLV = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_LLV).add_to(my_mapLLV)
my_mapLLV.save('LLV.html')
print("data save to LLV.html")
my_mapLLV
# Out:
# data save to LLV.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>INTIMIDATION</h1>
# <hr>

# %%
INTIMIDATION = chicago_crimes[chicago_crimes['Primary Type'] == "INTIMIDATION"]
INTIMIDATION_loc_list = INTIMIDATION.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_INTIMIDATION = INTIMIDATION_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapINTIMIDATION = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_INTIMIDATION).add_to(my_mapINTIMIDATION)
my_mapINTIMIDATION.save('INTIMIDATION.html')
print("data save to INTIMIDATION.html")
my_mapINTIMIDATION
# Out:
# data save to INTIMIDATION.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>KIDNAPPING</h1>
# <hr>

# %%
KIDNAPPING = chicago_crimes[chicago_crimes['Primary Type'] == "KIDNAPPING"]
KIDNAPPING_loc_list = KIDNAPPING.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_KIDNAPPING = KIDNAPPING_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapKIDNAPPING = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_KIDNAPPING).add_to(my_mapKIDNAPPING)
my_mapKIDNAPPING.save('KIDNAPPING.html')
print("data save to KIDNAPPING.html")
my_mapKIDNAPPING
# Out:
# data save to KIDNAPPING.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>HUMAN TRAFFICKING</h1>
# <hr>

# %%
HUMAN_TRAFFICKING = chicago_crimes[chicago_crimes['Primary Type'] == "HUMAN TRAFFICKING"]
HUMAN_TRAFFICKING_loc_list = HUMAN_TRAFFICKING.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_HUMAN_TRAFFICKING = HUMAN_TRAFFICKING_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapHUMAN_TRAFFICKING = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_HUMAN_TRAFFICKING).add_to(my_mapHUMAN_TRAFFICKING)
my_mapHUMAN_TRAFFICKING.save('HUMAN_TRAFFICKING.html')
print("data save to HUMAN_TRAFFICKING.html")
my_mapHUMAN_TRAFFICKING
# Out:
# data save to HUMAN_TRAFFICKING.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>GAMBLING</h1>
# <hr>

# %%
GAMBLING = chicago_crimes[chicago_crimes['Primary Type'] == "GAMBLING"]
GAMBLING_loc_list = GAMBLING.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_GAMBLING = GAMBLING_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapGAMBLING = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_GAMBLING).add_to(my_mapGAMBLING)
my_mapGAMBLING.save('GAMBLING.html')
print("data save to GAMBLING.html")
my_mapGAMBLING
# Out:
# data save to GAMBLING.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>PUBLIC INDECENCY</h1>
# <hr>

# %%
PUBLIC_INDECENCY = chicago_crimes[chicago_crimes['Primary Type'] == "PUBLIC INDECENCY"]
PUBLIC_INDECENCY_loc_list = PUBLIC_INDECENCY.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_PUBLIC_INDECENCY = PUBLIC_INDECENCY_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapPUBLIC_INDECENCY = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_PUBLIC_INDECENCY).add_to(my_mapPUBLIC_INDECENCY)
my_mapPUBLIC_INDECENCY.save('PUBLIC_INDECENCY.html')
print("data save to PUBLIC_INDECENCY.html")
my_mapPUBLIC_INDECENCY
# Out:
# data save to PUBLIC_INDECENCY.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>OTHER NARCOTIC VIOLATION</h1>
# <hr>

# %%
OTV = chicago_crimes[chicago_crimes['Primary Type'] == "OTHER NARCOTIC VIOLATION"]
OTV_loc_list = OTV.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_OTV = OTV_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapOTV = folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_OTV).add_to(my_mapOTV)
my_mapOTV.save('OTV.html')
print("data save to OTV.html")
my_mapOTV
# Out:
# data save to OTV.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# <h1>NON-CRIMINAL</h1>
# <hr>

# %%
NON_CRIMINAL = chicago_crimes[chicago_crimes['Primary Type'] == "NON-CRIMINAL"]
NON_CRIMINAL_loc_list = NON_CRIMINAL.groupby(['Latitude', 'Longitude']).size().reset_index(name = 'incident_count')
heatmap_NON_CRIMINAL = NON_CRIMINAL_loc_list[['Latitude', 'Longitude', 'incident_count']].values.tolist()
my_mapNON_CRIMINAL= folium.Map(location = [30,40], zoom_start = 4)
HeatMap(heatmap_NON_CRIMINAL).add_to(my_mapNON_CRIMINAL)
my_mapNON_CRIMINAL.save('NON_CRIMINAL.html')
print("data save to NON_CRIMINAL.html")
my_mapNON_CRIMINAL
# Out:
# data save to NON_CRIMINAL.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
